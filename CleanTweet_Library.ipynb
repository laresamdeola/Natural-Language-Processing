# %% [markdown]
# <a href="https://colab.research.google.com/github/laresamdeola/Natural-Language-Processing/blob/main/CleanTweet_Library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install cleantweet==2.0.2
# Out:
# ...
#   Attempting uninstall: cleantweet
#     Found existing installation: cleantweet 2.0.1
#     Uninstalling cleantweet-2.0.1:
#       Successfully uninstalled cleantweet-2.0.1
# ...

# %%
import cleantweet as clt

# %%
data = clt.CleanTweet('mini corpus for testing.txt')

# %%
print(data)

# %%
print(data.clean())
# Out:
# datafodderfigure I wrote a little or medium something about my experience writing and editing my memoircollection of personal essays icurehab Mental health morbity and suice in ICU survivors and caregivers icurehab AFbundle AshleighWildest Ofc not all of us have the choice to unmask some Black autistics and autistics of colour that element of temilys on the th i received this message on facebook suice overdose hanging rape self harm lesbiphobia can I watch military veos when i had my watching war footage phase i just found them on gif but trust me anon it is not good for you and will fuck you up if you keep watching it regularly legitimately a form of selfharm really wan na do self harm but why am i so scared Since the pandemic started claims for self harm up more than Anxiety up Substance abuse up these are for ages Portland Afternoon News KXLNewsI talk to AlbertinaKerrCEO Allison That firstminutes was the biggest act of self harm that has ever happened on television without a trigg
# ...

# %%
data = clt.DiagramTweet('mini corpus for testing.txt')
data.word_cloud()

# %%
data = clt.StatsTweet('mini corpus for testing.txt')
data.amount_of_proper_nouns(amount=10, plural=True)
# Out:
# {'words': ['Tories'], 'frequency': [1]}

# %%
data = clt.SentimentTweet('mini corpus for testing.txt')
data.vader()
# Out:
# ['datafodderfigure I wrote a little (or medium) something about my experience writing and editing my memoircollection of personal essays ab… icurehab Mental health morbity self‑harm and suice in ICU survivors and caregivers httpst.coLrfFnpLWI icurehab AFbundle AshleighWildest Ofc not all of us have the choice to unmask.', '\\n\\nFor some Black autistics and autistics of colour that element of visib… temilys on the th i received this message on facebook.', '‼️⚠️twslurs suice overdose hanging rape self harm lesbiphobia (another…Where can I watch military veos — when i had my watching war footage phase i just found them on gif but trust me anon it is not good for you and will fuck you up if you keep watching it regularly.', 'legitimately a form of selfharm httpst.coLcHmdkLxI really wanna do self harm but why am i so scared...Since the pandemic started claims for self harm up more than .', 'Anxiety up .', "Substance abuse up .And these are for ages .On Portland's Afternoon News KXLNewsI 
# ...

# %%
data = clt.SyntheticTweet('mini corpus for testing.txt')
data.rule_based()
# Out:
# harm
# harm firstminutes legitimately i
# suice is legitimately autistics
# harm is just i
# suice is legitimately suice
# autistics has overdose i
# harm is legitimately suice
# autistics is regularly autistics
# suice has not suice
# autistics trash legitimately datafodderfigure
# suice firstminutes regularly harm
